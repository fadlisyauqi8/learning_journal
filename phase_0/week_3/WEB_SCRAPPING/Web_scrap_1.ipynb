# %%
pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\thesevens\anaconda3\lib\site-packages (from bs4) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\thesevens\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.2.1)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py): started
#   Building wheel for bs4 (setup.py): finished with status 'done'
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1271 sha256=80eb0e909f481fbffcedcda7a197b092527fbd7257bb55abf894c05c9821799d
#   Stored in directory: c:\users\thesevens\appdata\local\pip\cache\wheels\73\2b\cb\099980278a0c9a3e57ff1a89875ec07bfa0b6fcbebb9a8cad3
# Successfully built bs4
# Installing collected packages: bs4
# Successfully installed bs4-0.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\thesevens\anaconda3\lib\site-packages (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thesevens\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thesevens\anaconda3\lib\site-packages (from requests) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\thesevens\anaconda3\lib\site-packages (from requests) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\thesevens\anaconda3\lib\site-packages (from requests) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install selenium
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\TheSevenS\anaconda3
#
#
# Note: you may need to restart the kernel to use updated packages.
#   added / updated specs:
#     - selenium
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.12.0               |   py39haa95532_0        14.5 MB
#     selenium-3.141.0           |py39h2bbff1b_1000         815 KB
#     ------------------------------------------------------------
#                                            Total:        15.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   selenium           pkgs/main/win-64::selenium-3.141.0-py39h2bbff1b_1000
#
# The following packages will be UPDATED:
#
#   conda                               4.10.3-py39haa95532_0 --> 4.12.0-py39haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# selenium-3.141.0     | 815 KB    |            |   0%
# selenium-3.141.0     | 815 KB    | 1          |   2%
# selenium-3.141.0     | 815 KB    | ####5      |  45%
# selenium-3.141.0     | 815 KB    | ########6  |  86%
# selenium-3.141.0     | 815 KB    | ########## | 100%
#
# conda-4.12.0         | 14.5 MB   |            |   0%
# conda-4.12.0         | 14.5 MB   | ####5      |  45%
# conda-4.12.0         | 14.5 MB   | ########7  |  88%
# conda-4.12.0         | 14.5 MB   | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %% [markdown]
# ## Access Web

# %%
import requests
page = requests.get("https://www.gramedia.com/categories/buku")
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
driver = webdriver.Chrome('chromedriver')

url="https://www.gramedia.com/categories/buku"
driver.get(url)
html = driver.page_source

soup = BeautifulSoup(html, "html.parser")
print(soup.prettify()[:700])
# Out:
# <html class="" lang="id">
#  <head>
#   <base href="/"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="#281e5a" name="theme-color"/>
#   <meta content="index, follow" name="robots"/>
#   <link href="/assets/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="manifest.json" rel="manifest"/>
#   <link href="/assets/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="z91Vp6ZYo9UoX5D4ur6i4Lrl0l1j3DDoCH08fD3n53g" name="google-site-verification"/>
#   <meta content="810657685650228" property="fb:app_id"/>
#   <style>
#    .async-hide {
#         opacity: 0 !important
#     }
#   </style>
#   <script async="" src="https://app.

# %%
soup.find_all('div',{"class":"list-title"})
# Out:
# [<div _ngcontent-web-gramedia-c26="" class="list-title">Kisah Teladan 10 Sahabat Nabi yang Dijamin Masuk Surga</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Kisah Teladan 25 Nabi &amp; Rasul</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Komunikasi Keperawatan X</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Praktikum Akunt.Perusahaan Jasa,Dagang Xii Smk K13</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xii Asesmen B. Indonesia 3 Kur. 13 Ed. Rev</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xii Otomatisasi Tata Kelola Kepegawaian Kur. 13</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xii Otomatisasi Tata Kelola Humas Dan Keprotoko</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xii Matematika 3 Kelompok Nonteknik Kur. 13 Ed.</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xii Akuntansi Perbankan Syariah 2 Kur. 13 Ed. R</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xii Administrasi Infrastruktur Jaringan 2 Kur.</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xi Pemrograman Berorientasi Objek 1 Kur. 13 Ed.</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. X Pelayanan Prima</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. X Etika Profesi Prog. Akuntansi Dan Keuangan Ku</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xi Pemeliharaan Mesin Kendaraan Ringan Kur. 13</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xi Animasi 2D Dan 3D Kur. 13 Ed. Rev</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Dago Love Story: Mentari untuk Dago</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">30 Hari Pintar Membaca Untuk Anak 4-6 Tahun</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Dari Aku Yang Hampir Menyerah</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xi Industri Perhotelan Kur. 13 Ed. Rev</div>,
#  <div _ngcontent-web-gramedia-c26="" class="list-title">Smk/Mak Kls. Xi Gambar Teknik Manufaktur 1 Kur. 13 Ed. Rev</div>]

# %%
for div_tag in soup.find_all('div',{"class":"list-title"}):
    print(div_tag.get_text())
# Out:
# Kisah Teladan 10 Sahabat Nabi yang Dijamin Masuk Surga
# Kisah Teladan 25 Nabi & Rasul
# Komunikasi Keperawatan X
# Praktikum Akunt.Perusahaan Jasa,Dagang Xii Smk K13
# Smk/Mak Kls. Xii Asesmen B. Indonesia 3 Kur. 13 Ed. Rev
# Smk/Mak Kls. Xii Otomatisasi Tata Kelola Kepegawaian Kur. 13
# Smk/Mak Kls. Xii Otomatisasi Tata Kelola Humas Dan Keprotoko
# Smk/Mak Kls. Xii Matematika 3 Kelompok Nonteknik Kur. 13 Ed.
# Smk/Mak Kls. Xii Akuntansi Perbankan Syariah 2 Kur. 13 Ed. R
# Smk/Mak Kls. Xii Administrasi Infrastruktur Jaringan 2 Kur.
# Smk/Mak Kls. Xi Pemrograman Berorientasi Objek 1 Kur. 13 Ed.
# Smk/Mak Kls. X Pelayanan Prima
# Smk/Mak Kls. X Etika Profesi Prog. Akuntansi Dan Keuangan Ku
# Smk/Mak Kls. Xi Pemeliharaan Mesin Kendaraan Ringan Kur. 13
# Smk/Mak Kls. Xi Animasi 2D Dan 3D Kur. 13 Ed. Rev
# Dago Love Story: Mentari untuk Dago
# 30 Hari Pintar Membaca Untuk Anak 4-6 Tahun
# Dari Aku Yang Hampir Menyerah
# Smk/Mak Kls. Xi Industri Perhotelan Kur. 13 Ed. Rev
# Smk/Mak Kls. Xi Gambar Teknik Manufaktur 1 Kur. 13 Ed. Rev

# %%
import pandas as pd

data = pd.DataFrame()

data['Title'] = [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
data['Author'] = [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
data['Price'] = [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
data['Image'] = [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

links = []
for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
    try:
        links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
    except:
        pass

data['Link'] = links

data
# Out:
#                                                 Title  \
# 0   Kisah Teladan 10 Sahabat Nabi yang Dijamin Mas...
# 1                       Kisah Teladan 25 Nabi & Rasul
# 2                            Komunikasi Keperawatan X
# 3   Praktikum Akunt.Perusahaan Jasa,Dagang Xii Smk...
# 4   Smk/Mak Kls. Xii Asesmen B. Indonesia 3 Kur. 1...
# 5   Smk/Mak Kls. Xii Otomatisasi Tata Kelola Kepeg...
# 6   Smk/Mak Kls. Xii Otomatisasi Tata Kelola Humas...
# 7   Smk/Mak Kls. Xii Matematika 3 Kelompok Nontekn...
# 8   Smk/Mak Kls. Xii Akuntansi Perbankan Syariah 2...
# 9   Smk/Mak Kls. Xii Administrasi Infrastruktur Ja...
# 10  Smk/Mak Kls. Xi Pemrograman Berorientasi Objek...
# 11                     Smk/Mak Kls. X Pelayanan Prima
# 12  Smk/Mak Kls. X Etika Profesi Prog. Akuntansi D...
# 13  Smk/Mak Kls. Xi Pemeliharaan Mesin Kendaraan R...
# 14  Smk/Mak Kls. Xi Animasi 2D Dan 3D Kur. 13 Ed. Rev
# 15                Dago Love Story: Mentari untuk Dago
# 16        30 Hari Pintar Membaca Untuk Anak 4-6 Tahun
# 17                      Dari Aku Yang Hampir Menyerah
# 18  Smk/Mak Kls. Xi Industri Perhotelan Kur. 13 Ed...
# 19  Smk/Mak Kls. Xi Gambar Teknik Manufaktur 1 Kur...
#
#                           Author      Price  \
# 0                  Agus Mutaram   Rp 48.000
# 1                  Agus Mutaram   Rp 48.000
# 2        Tim Dharma Aksara None   Rp 58.000
# 3                  Azzam Gahara   Rp 66.000
# 4              TIM EDI YGI None   Rp 44.000
# 5              Tim Darma Aksara   Rp 66.000
# 6                   TEZAR QOYIM   Rp 72.000
# 7              S.N. Sharma None   Rp 82.000
# 8    Eltine Regiena Prawitasari   Rp 62.000
# 9          Dendi Arafah Suhandi   Rp 60.000
# 10             Yuyun Tresnawati   Rp 63.000
# 11              Rina Kuswardani   Rp 59.000
# 12             Rikki Firmansyah   Rp 60.000
# 13                  Parlan None   Rp 66.000
# 14                 RIDA MULYADI   Rp 85.000
# 15               SKYSPHIRE None   Rp 99.000
# 16                  FANNY NOVIA   Rp 48.000
# 17                KHOIRUL TRIAN   Rp 79.000
# 18                 Erna Marlina   Rp 60.000
# 19           Yon Fatkhunal Huda   Rp 60.000
#
#                                                 Image  \
# 0   https://cdn.gramedia.com/uploads/items/Kisah_T...
# 1   https://cdn.gramedia.com/uploads/items/Kisah_T...
# 2                  /assets/default-images/product.png
# 3   https://cdn.gramedia.com/uploads/items/img2022...
# 4                  /assets/default-images/product.png
# 5                  /assets/default-images/product.png
# 6                  /assets/default-images/product.png
# 7                  /assets/default-images/product.png
# 8                  /assets/default-images/product.png
# 9                  /assets/default-images/product.png
# 10                 /assets/default-images/product.png
# 11                 /assets/default-images/product.png
# 12                 /assets/default-images/product.png
# 13                 /assets/default-images/product.png
# 14                 /assets/default-images/product.png
# 15                 /assets/default-images/product.png
# 16                 /assets/default-images/product.png
# 17                 /assets/default-images/product.png
# 18                 /assets/default-images/product.png
# 19                 /assets/default-images/product.png
#
#                                                  Link
# 0   https://www.gramedia.com/products/kisah-telada...
# 1   https://www.gramedia.com/products/kisah-telada...
# 2   https://www.gramedia.com/products/komunikasi-k...
# 3   https://www.gramedia.com/products/praktikum-ak...
# 4   https://www.gramedia.com/products/smkmak-kls-x...
# 5   https://www.gramedia.com/products/smkmak-kls-x...
# 6   https://www.gramedia.com/products/smkmak-kls-x...
# 7   https://www.gramedia.com/products/smkmak-kls-x...
# 8   https://www.gramedia.com/products/smkmak-kls-x...
# 9   https://www.gramedia.com/products/smkmak-kls-x...
# 10  https://www.gramedia.com/products/smkmak-kls-x...
# 11  https://www.gramedia.com/products/smkmak-kls-x...
# 12  https://www.gramedia.com/products/smkmak-kls-x...
# 13  https://www.gramedia.com/products/smkmak-kls-x...
# 14  https://www.gramedia.com/products/smkmak-kls-x...
# 15  https://www.gramedia.com/products/dago-love-st...
# 16  https://www.gramedia.com/products/30-hari-pint...
# 17  https://www.gramedia.com/products/dari-aku-yan...
# 18  https://www.gramedia.com/products/smkmak-kls-x...
# 19  https://www.gramedia.com/products/smkmak-kls-x...

# %% [markdown]
# ## Multipage

# %%
title = []
author = []
price = []
image = []
Links = []

driver = webdriver.Chrome('chromedriver')

for i in range(1,21):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    title += [ title.get_text() for title in soup.find_all( 'div', {"class":"list-title"} ) ]
    author += [ author.get_text() for author in soup.find_all( 'p', {"class":"div-author"} ) ]
    price += [ price.get_text() for price in soup.find_all( 'p', {"class":"formats-price"} ) ]
    image += [ img['src'] for img in soup.find_all( 'img',{"class":"product-list-img"} ) ]

    links = []
    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            links.append("https://www.gramedia.com"+tag.find_all('a',{"_ngcontent-web-gramedia-c26":""})[0]['href'])
        except:
            pass
    Links += links

data_multipage = pd.DataFrame()
data_multipage['Title'] = title
data_multipage['Author'] = author
data_multipage['Price'] = price
data_multipage['Image'] = image
data_multipage['Link'] = Links

data_multipage
# Out:
#                                                  Title  \
# 0                 Alquran Cordoba Amal Niaga Tajwid A4
# 1                           Al-Qur'an Cordoba Niaga B5
# 2                         Al-Quran Cordoba Al Akrom A5
# 3                         Al-Quran Cordoba Al Akrom B5
# 4    Smk/Mak Kls. Xii Otomatisasi Tata Kelola Saran...
# ..                                                 ...
# 135                       Make Nothing to be Something
# 136         Istikamah Itu Berat, Yang Ringan Istirahat
# 137                  Nabi Tak Pernah Mengajarkan Malas
# 138                           Self Healing With Qur`An
# 139        Mengeksplorasi Fungsi INDEX dan MATCH Excel
#
#                                    Author       Price  \
# 0     Pt Cordoba International Indonesia   Rp 246.000
# 1                                          Rp 169.000
# 2     Pt Cordoba International Indonesia    Rp 49.000
# 3     Pt Cordoba International Indonesia    Rp 67.000
# 4                          Dwi Kurniawan    Rp 70.000
# ..                                    ...         ...
# 135                          Yamin Lubis    Rp 95.000
# 136                       Haidar Musyafa    Rp 59.000
# 137                        Zaka Putra R.    Rp 62.000
# 138                      Ummu Kalsum Iqt    Rp 53.000
# 139      Yudhy Wicaksono & Solusi Kantor    Rp 80.000
#
#                                                  Image  \
# 0    https://cdn.gramedia.com/uploads/items/img2022...
# 1    https://cdn.gramedia.com/uploads/items/img2022...
# 2    https://cdn.gramedia.com/uploads/items/img2022...
# 3    https://cdn.gramedia.com/uploads/items/img2022...
# 4                   /assets/default-images/product.png
# ..                                                 ...
# 135                 /assets/default-images/product.png
# 136                 /assets/default-images/product.png
# 137                 /assets/default-images/product.png
# 138                 /assets/default-images/product.png
# 139                 /assets/default-images/product.png
#
#                                                   Link
# 0    https://www.gramedia.com/products/alquran-cord...
# 1    https://www.gramedia.com/products/al-quran-cor...
# 2    https://www.gramedia.com/products/al-quran-cor...
# 3    https://www.gramedia.com/products/al-quran-cor...
# 4    https://www.gramedia.com/products/smkmak-kls-x...
# ..                                                 ...
# 135  https://www.gramedia.com/products/make-nothing...
# 136  https://www.gramedia.com/products/istikamah-it...
# 137  https://www.gramedia.com/products/nabi-tak-per...
# 138  https://www.gramedia.com/products/self-healing...
# 139  https://www.gramedia.com/products/mengeksplora...
#
# [140 rows x 5 columns]

# %% [markdown]
# ## Accessing Invidual Page

# %%
title = []
author = []
price = []
desc = []
num_pages = []
date_issue = []
publisher = []

driver = webdriver.Chrome('chromedriver')

for i in range(1,3):
    url="https://www.gramedia.com/categories/buku?page={}".format(i)
    driver.get(url)
    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")

    for tag in soup.find_all( 'div',{"_ngcontent-web-gramedia-c26":"","class":"ng-star-inserted"} ):
        try:
            link = "https://www.gramedia.com"+tag.find('a',{"_ngcontent-web-gramedia-c26":""})['href']
            driver.get(link)
            html_ind = driver.page_source
            soup_ind = BeautifulSoup(html_ind, "html.parser")

            title.append( soup_ind.find( 'div', {"class":"book-title"} ).get_text() )
            author.append( soup_ind.find('span',{"class":"title-author"}).get_text() )
            price.append( soup_ind.find('div', {'class':'price-product'}).get_text() )
            desc.append( soup_ind.find('pre').get_text() )
            num_pages.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[0].get_text() )
            date_issue.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[2].get_text() )
            publisher.append( soup_ind.find('div',{'class':'detail-section'}).find_all('p')[1].get_text() )

        except:
            pass

pages = pd.DataFrame()
pages['Title'] = title
pages['Author'] = author
pages['Price'] = price
pages['Desc'] = desc
pages['Num Pages'] = num_pages
pages['Date Issue'] = date_issue
pages['Publisher'] = publisher

pages
# Out:
# Empty DataFrame
# Columns: [Title, Author, Price, Desc, Num Pages, Date Issue, Publisher]
# Index: []
